# %%
import pandas as pd


df = pd.read_csv('data.csv')

# %%
# delete every row that has  'could not extract' in the row some text

df = df[~df.apply(lambda row: row.astype(str).str.contains('Could not extract').any(), axis=1)]

# %%
df
# Out:
#                Name                                        ProfileLink  Age  \
# 0             Gabin  https://docs.google.com/document/d/1ymul6X3DQH...   25
# 2            Callum  https://docs.google.com/document/d/16Li0PY9WG5...   40
# 3        Ari Zerner                     https://arizerner.com/date-me/   27
# 5              Mike  https://docs.google.com/document/d/1AvSdS2EUh4...   31
# 6          Alicia C  https://aecombs.notion.site/Date-Alicia-471a13...   33
# ..              ...                                                ...  ...
# 473  Rachel Clifton  https://docs.google.com/document/d/1_Xjg6U_n5W...   24
# 474            Dony  https://docs.google.com/document/d/1PfWxS-Xl_K...   27
# 477  Blaïse (bless)  https://docs.google.com/document/d/1ndGs9G9SvG...   38
# 478   Brian Tomasik        https://briantomasik.com/my-dating-profile/   35
# 479             Wes  https://docs.google.com/document/d/1w2jH3CRis1...   39
#
#     Gender InterestedIn       Style  \
# 0        M        F, NB         Any
# 2        M            F        mono
# 3        M        F, NB        poly
# 5        M            F        mono
# 6        F     F, M, NB        poly
# ..     ...          ...         ...
# 473      F            M  poly, mono
# 474      M     F, M, NB         NaN
# 477     NB            M        mono
# 478      M        F, NB        mono
# 479      M            F        poly
#
#                                       Location LocationFlexibility  \
# 0              Central Europe, South of France                Some
# 2                                           UK            Flexible
# 3         San Francisco Bay Area, Philadelphia                Some
# 5    North America, Flexible, Philadelphia, PA            Flexible
# 6                       San Francisco Bay Area                Some
# ..                                         ...                 ...
# 473                                     London            Flexible
# 474                     San Francisco Bay Area                 NaN
# 477                               Ladysmith BC                 NaN
# 478                                         NY            Flexible
# 479                           Collingswood, NJ                 NaN
#
#                                      Contact LastUpdated  \
# 0                   GabinDatingDoc@proton.me  2025-03-07
# 2                callumcallum109@outlook.com  2025-03-04
# 3                             ari@zerner.com  2025-02-24
# 5                          please see doc :)  2025-02-20
# 6                  alicia.combs.92@gmail.com  2025-02-18
# ..                                       ...         ...
# 473                   twitter.com/rachelclif  2023-01-23
# 474  https://calendly.com/donychristie/30min  2022-10-16
# 477                     Academia_nut@shaw.ca  2022-10-14
# 478                                      NaN  2022-10-01
# 479                                      NaN  2022-09-29
#
#                                            ProfileText
# 0    ﻿Hi!\r\nThis is a dating doc, I’m a 25 year ol...
# 2    ﻿In as many words\r\n\r\n\r\nTo love and be lo...
# 3    Ari's Date Me Doc | Ari Zerner's Demesne\nAri ...
# 5    ﻿Mike’s Date-Me Doc\r\n\r\n\r\n\r\n\r\nHi, tha...
# 6    Your connected workspace for wiki, docs & proj...
# ..                                                 ...
# 473  ﻿This document is a social experiment. \r\nIt’...
# 474                                                  ﻿
# 477  ﻿Dating Stephen Blaïse Saint Clare\r\n\r\n\r\n...
# 478  My dating profile\nHome\n•\nWritings\nMy datin...
# 479  ﻿BESPOKE 1983 NONMONOGAMOUS DAD MODEL, AVAILAB...
#
# [342 rows x 11 columns]

# %%
all_matches = []  # Global list to track matched pairs (stored as strings like "rowA:rowB")

def checkLocation(row1, row2):
    if pd.isna(row1['LocationFlexibility']) or pd.isna(row2['LocationFlexibility']):
        loc1 = str(row1['Location']).split(',')
        loc2 = str(row2['Location']).split(',')

        for locs in loc1:
            if locs in loc2:
                return True


    else:
        return True

    return False

def get_matches(row):
    my_gen = row['Gender'].strip()
    my_want = [x.strip() for x in str(row['InterestedIn']).split(',')]
    
    matches = []  # Initialize the matches list for this row
    
    for idx, other_row in df.iterrows():
        if idx == row.name:  # Skip self
            continue
        
        # Check if other's gender is in my desired list
        if other_row['Gender'].strip() in my_want:
            # Check if my gender is in their desired list
            other_want = [x.strip() for x in str(other_row['InterestedIn']).split(',')]
            if my_gen in other_want:
                # Check if the pair already exists in either order
                pair1 = f"{row.name}:{other_row.name}"
                pair2 = f"{other_row.name}:{row.name}"
                
                if pair1 not in all_matches and pair2 not in all_matches:
                    # If not present, add to all_matches and record the match

                    if checkLocation(row, other_row):

                        all_matches.append(pair1)  # Track the pair in one direction
                        matches.append(other_row.name)  # Append the other user's name
                    
    return matches  # Return the matches list (not the entire row)

# Apply the function and assign to 'matches' column
df['matches'] = df.apply(get_matches, axis=1)
# Out:
# ['Central Europe', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe', ' South of France']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Central Europe', ' South of France']
# ['Chicago']
# ['Central Europe', ' South of France']
# ['NYC']
# ['Central Europe', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe', ' South of France']
# ['Boston']
# ['Central Europe', ' South of France']
# ['DC', ' Philadelphia']
# ['Central Europe', ' South of France']
# ['nan']
# ['Central Europe', ' South of France']
# ['nan']
# ['Central Europe', ' South of France']
# ['nan']
# ['Central Europe', ' South of France']
# ['Toronto']
# ['Central Europe', ' South of France']
# ['nan']
# ['Central Europe', ' South of France']
# ['London']
# ['Central Europe', ' South of France']
# ['NYC']
# ['Central Europe', ' South of France']
# ['Ladysmith BC']
# ['Central Europe', ' South of France']
# ['Los Angeles']
# ['Central Europe', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe', ' South of France']
# ['NYC']
# ['Central Europe', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe', ' South of France']
# ['Ladysmith BC']
# ['UK']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['UK']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['UK']
# ['Chicago']
# ['UK']
# ['NYC']
# ['UK']
# ['San Francisco Bay Area']
# ['UK']
# ['Boston']
# ['UK']
# ['DC', ' Philadelphia']
# ['UK']
# ['nan']
# ['UK']
# ['nan']
# ['UK']
# ['nan']
# ['UK']
# ['Toronto']
# ['UK']
# ['nan']
# ['UK']
# ['London']
# ['UK']
# ['NYC']
# ['UK']
# ['Ladysmith BC']
# ['UK']
# ['Los Angeles']
# ['UK']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['UK']
# ['NYC']
# ['UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Chicago']
# ['San Francisco Bay Area', ' Philadelphia']
# ['NYC']
# ['San Francisco Bay Area', ' Philadelphia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Boston']
# ['San Francisco Bay Area', ' Philadelphia']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area', ' Philadelphia']
# ['nan']
# ['San Francisco Bay Area', ' Philadelphia']
# ['nan']
# ['San Francisco Bay Area', ' Philadelphia']
# ['nan']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Toronto']
# ['San Francisco Bay Area', ' Philadelphia']
# ['nan']
# ['San Francisco Bay Area', ' Philadelphia']
# ['London']
# ['San Francisco Bay Area', ' Philadelphia']
# ['NYC']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Ladysmith BC']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Los Angeles']
# ['San Francisco Bay Area', ' Philadelphia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['NYC']
# ['San Francisco Bay Area', ' Philadelphia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Ladysmith BC']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['San Francisco Bay Area']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['San Francisco Bay Area']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['Chicago']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['NYC']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['San Francisco Bay Area']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['Boston']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['DC', ' Philadelphia']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['nan']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['nan']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['nan']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['Toronto']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['nan']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['London']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['NYC']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['Ladysmith BC']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['Los Angeles']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['San Francisco Bay Area']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['San Francisco Bay Area']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['NYC']
# ['North America', ' Flexible', ' Philadelphia', ' PA']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Berkeley']
# ['San Francisco Bay Area']
# ['Los Angeles', ' Western US']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Southern US']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Seattle', ' WA', ' Western US', ' North America']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['NYC', ' NJ']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['Brazil']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['CT', ' New Haven']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['Berkeley', ' San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['PA', ' Philadelphia']
# ['San Francisco Bay Area']
# ['South of France']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Denver', ' Colorado']
# ['San Francisco Bay Area']
# ['Western US']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['Spain']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area']
# ['Norway']
# ['San Francisco Bay Area']
# ['Israel']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible', ' NY']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Sacramento', ' Monterey']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['Los Angeles', ' Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['Flexible', ' UK']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' North America']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Boston']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Seoul']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Seattle', ' WA', ' Flexible']
# ['San Francisco Bay Area']
# ['WI']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Boston', ' MA']
# ['San Francisco Bay Area']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' London', ' Brighton', ' Seattle', ' Southern US', ' TX', ' NJ', ' Sweden', ' Los Angeles', ' Sydney Australia', ' ON', ' North Carolina', ' Boston', ' North America', ' Toronto', ' Canada', ' Flexible', ' Philadelphia', ' UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Seattle', ' Boston', ' Western US']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['Brighton']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['PA']
# ['San Francisco Bay Area']
# ['Central Europe', ' Berlin']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Los Angeles']
# ['San Francisco Bay Area']
# ['Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Oregon']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Seoul', ' Asia', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Amsterdam']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Vancouver']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Austin']
# ['San Francisco Bay Area']
# ['Oxford']
# ['San Francisco Bay Area']
# ['NY', ' NYC']
# ['San Francisco Bay Area']
# ['London', ' Brighton']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['London']
# ['Sacramento']
# ['San Francisco Bay Area', ' Berkeley']
# ['Sacramento']
# ['Los Angeles', ' Western US']
# ['Sacramento']
# ['DC']
# ['Sacramento']
# ['nan']
# ['Sacramento']
# ['Southern US']
# ['Sacramento']
# ['NYC']
# ['Sacramento']
# ['nan']
# ['Sacramento']
# ['Central Europe']
# ['Sacramento']
# ['Los Angeles']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['NYC']
# ['Sacramento']
# ['nan']
# ['Sacramento']
# ['NYC']
# ['Sacramento']
# ['Asia']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['NYC']
# ['Sacramento']
# ['Seattle', ' WA', ' Western US', ' North America']
# ['Sacramento']
# ['London', ' UK']
# ['Sacramento']
# ['UK']
# ['Sacramento']
# ['NYC', ' NJ']
# ['Sacramento']
# ['Brazil']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['CT', ' New Haven']
# ['Sacramento']
# ['Berlin']
# ['Sacramento']
# ['Berlin']
# ['Sacramento']
# ['Berkeley', ' San Francisco Bay Area']
# ['Sacramento']
# ['London']
# ['Sacramento']
# ['PA', ' Philadelphia']
# ['Sacramento']
# ['South of France']
# ['Sacramento']
# ['NYC']
# ['Sacramento']
# ['Denver', ' Colorado']
# ['Sacramento']
# ['Western US']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['London', ' UK']
# ['Chicago']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['Boston']
# ['London', ' UK']
# ['DC', ' Philadelphia']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['Toronto']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['London']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['Ladysmith BC']
# ['London', ' UK']
# ['Los Angeles']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['Spain']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area']
# ['Norway']
# ['San Francisco Bay Area']
# ['Israel']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible', ' NY']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Sacramento', ' Monterey']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['Los Angeles', ' Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['Flexible', ' UK']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' North America']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Boston']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Seoul']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Seattle', ' WA', ' Flexible']
# ['San Francisco Bay Area']
# ['WI']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Boston', ' MA']
# ['San Francisco Bay Area']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' London', ' Brighton', ' Seattle', ' Southern US', ' TX', ' NJ', ' Sweden', ' Los Angeles', ' Sydney Australia', ' ON', ' North Carolina', ' Boston', ' North America', ' Toronto', ' Canada', ' Flexible', ' Philadelphia', ' UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Seattle', ' Boston', ' Western US']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['Brighton']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['PA']
# ['San Francisco Bay Area']
# ['Central Europe', ' Berlin']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Los Angeles']
# ['San Francisco Bay Area']
# ['Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Oregon']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Seoul', ' Asia', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Amsterdam']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Vancouver']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Austin']
# ['San Francisco Bay Area']
# ['Oxford']
# ['San Francisco Bay Area']
# ['NY', ' NYC']
# ['San Francisco Bay Area']
# ['London', ' Brighton']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['London']
# ['North America']
# ['San Francisco Bay Area', ' Berkeley']
# ['North America']
# ['Los Angeles', ' Western US']
# ['North America']
# ['DC']
# ['North America']
# ['nan']
# ['North America']
# ['Southern US']
# ['North America']
# ['NYC']
# ['North America']
# ['nan']
# ['North America']
# ['Central Europe']
# ['North America']
# ['Los Angeles']
# ['North America']
# ['Chicago']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['NYC']
# ['North America']
# ['nan']
# ['North America']
# ['NYC']
# ['North America']
# ['Asia']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['nan']
# ['North America']
# ['NYC']
# ['North America']
# ['Seattle', ' WA', ' Western US', ' North America']
# ['North America']
# ['London', ' UK']
# ['North America']
# ['UK']
# ['North America']
# ['NYC', ' NJ']
# ['North America']
# ['Los Angeles']
# ['North America']
# ['Brazil']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['CT', ' New Haven']
# ['North America']
# ['Berlin']
# ['North America']
# ['Berlin']
# ['North America']
# ['Berkeley', ' San Francisco Bay Area']
# ['North America']
# ['London']
# ['North America']
# ['PA', ' Philadelphia']
# ['North America']
# ['South of France']
# ['North America']
# ['NYC']
# ['North America']
# ['Denver', ' Colorado']
# ['North America']
# ['Western US']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['Collingswood', ' NJ']
# ['Philadelphia']
# ['San Francisco Bay Area']
# ['Philadelphia']
# ['San Francisco Bay Area']
# ['Philadelphia']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Philadelphia']
# ['Chicago']
# ['Philadelphia']
# ['NYC']
# ['Philadelphia']
# ['San Francisco Bay Area']
# ['Philadelphia']
# ['Boston']
# ['Philadelphia']
# ['DC', ' Philadelphia']
# ['Philadelphia']
# ['nan']
# ['Philadelphia']
# ['nan']
# ['Philadelphia']
# ['nan']
# ['Philadelphia']
# ['Toronto']
# ['Philadelphia']
# ['nan']
# ['Philadelphia']
# ['London']
# ['Philadelphia']
# ['NYC']
# ['Philadelphia']
# ['Ladysmith BC']
# ['Philadelphia']
# ['Los Angeles']
# ['Philadelphia']
# ['San Francisco Bay Area']
# ['Philadelphia']
# ['San Francisco Bay Area']
# ['Philadelphia']
# ['NYC']
# ['Philadelphia']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['UK', ' Oxford']
# ['Chicago']
# ['UK', ' Oxford']
# ['NYC']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['Boston']
# ['UK', ' Oxford']
# ['DC', ' Philadelphia']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['Toronto']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['London']
# ['UK', ' Oxford']
# ['NYC']
# ['UK', ' Oxford']
# ['Ladysmith BC']
# ['UK', ' Oxford']
# ['Los Angeles']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['NYC']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['Spain']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area']
# ['Norway']
# ['San Francisco Bay Area']
# ['Israel']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible', ' NY']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Sacramento', ' Monterey']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['Los Angeles', ' Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['Flexible', ' UK']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' North America']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Boston']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Seoul']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Seattle', ' WA', ' Flexible']
# ['San Francisco Bay Area']
# ['WI']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Boston', ' MA']
# ['San Francisco Bay Area']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' London', ' Brighton', ' Seattle', ' Southern US', ' TX', ' NJ', ' Sweden', ' Los Angeles', ' Sydney Australia', ' ON', ' North Carolina', ' Boston', ' North America', ' Toronto', ' Canada', ' Flexible', ' Philadelphia', ' UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Seattle', ' Boston', ' Western US']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['Brighton']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['PA']
# ['San Francisco Bay Area']
# ['Central Europe', ' Berlin']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Los Angeles']
# ['San Francisco Bay Area']
# ['Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Oregon']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Seoul', ' Asia', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Amsterdam']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Vancouver']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Austin']
# ['San Francisco Bay Area']
# ['Oxford']
# ['San Francisco Bay Area']
# ['NY', ' NYC']
# ['San Francisco Bay Area']
# ['London', ' Brighton']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Berkeley']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['North America']
# ['Chicago']
# ['North America']
# ['NYC']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['Boston']
# ['North America']
# ['DC', ' Philadelphia']
# ['North America']
# ['nan']
# ['North America']
# ['nan']
# ['North America']
# ['nan']
# ['North America']
# ['Toronto']
# ['North America']
# ['nan']
# ['North America']
# ['London']
# ['North America']
# ['NYC']
# ['North America']
# ['Ladysmith BC']
# ['North America']
# ['Los Angeles']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['North America']
# ['NYC']
# ['North America']
# ['San Francisco Bay Area']
# ['London', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London', ' UK', ' Oxford']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['London', ' UK', ' Oxford']
# ['Chicago']
# ['London', ' UK', ' Oxford']
# ['NYC']
# ['London', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London', ' UK', ' Oxford']
# ['Boston']
# ['London', ' UK', ' Oxford']
# ['DC', ' Philadelphia']
# ['London', ' UK', ' Oxford']
# ['nan']
# ['London', ' UK', ' Oxford']
# ['nan']
# ['London', ' UK', ' Oxford']
# ['nan']
# ['London', ' UK', ' Oxford']
# ['Toronto']
# ['London', ' UK', ' Oxford']
# ['nan']
# ['London', ' UK', ' Oxford']
# ['London']
# ['London', ' UK', ' Oxford']
# ['NYC']
# ['London', ' UK', ' Oxford']
# ['Ladysmith BC']
# ['London', ' UK', ' Oxford']
# ['Los Angeles']
# ['London', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London', ' UK', ' Oxford']
# ['NYC']
# ['London', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['UK', ' Oxford']
# ['Chicago']
# ['UK', ' Oxford']
# ['NYC']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['Boston']
# ['UK', ' Oxford']
# ['DC', ' Philadelphia']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['Toronto']
# ['UK', ' Oxford']
# ['nan']
# ['UK', ' Oxford']
# ['London']
# ['UK', ' Oxford']
# ['NYC']
# ['UK', ' Oxford']
# ['Ladysmith BC']
# ['UK', ' Oxford']
# ['Los Angeles']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['UK', ' Oxford']
# ['NYC']
# ['UK', ' Oxford']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Boston']
# ['San Francisco Bay Area']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['London']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area', ' Berkeley']
# ['DC', ' North America', ' Flexible']
# ['Los Angeles', ' Western US']
# ['DC', ' North America', ' Flexible']
# ['DC']
# ['DC', ' North America', ' Flexible']
# ['nan']
# ['DC', ' North America', ' Flexible']
# ['Southern US']
# ['DC', ' North America', ' Flexible']
# ['NYC']
# ['DC', ' North America', ' Flexible']
# ['nan']
# ['DC', ' North America', ' Flexible']
# ['Central Europe']
# ['DC', ' North America', ' Flexible']
# ['Los Angeles']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['NYC']
# ['DC', ' North America', ' Flexible']
# ['nan']
# ['DC', ' North America', ' Flexible']
# ['NYC']
# ['DC', ' North America', ' Flexible']
# ['Asia']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['NYC']
# ['DC', ' North America', ' Flexible']
# ['Seattle', ' WA', ' Western US', ' North America']
# ['DC', ' North America', ' Flexible']
# ['London', ' UK']
# ['DC', ' North America', ' Flexible']
# ['UK']
# ['DC', ' North America', ' Flexible']
# ['NYC', ' NJ']
# ['DC', ' North America', ' Flexible']
# ['Brazil']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['CT', ' New Haven']
# ['DC', ' North America', ' Flexible']
# ['Berlin']
# ['DC', ' North America', ' Flexible']
# ['Berlin']
# ['DC', ' North America', ' Flexible']
# ['Berkeley', ' San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['London']
# ['DC', ' North America', ' Flexible']
# ['PA', ' Philadelphia']
# ['DC', ' North America', ' Flexible']
# ['South of France']
# ['DC', ' North America', ' Flexible']
# ['NYC']
# ['DC', ' North America', ' Flexible']
# ['Denver', ' Colorado']
# ['DC', ' North America', ' Flexible']
# ['Western US']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['London', ' UK']
# ['Chicago']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['Boston']
# ['London', ' UK']
# ['DC', ' Philadelphia']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['Toronto']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['London']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['Ladysmith BC']
# ['London', ' UK']
# ['Los Angeles']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Flexible']
# ['Chicago']
# ['Flexible']
# ['NYC']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['Boston']
# ['Flexible']
# ['DC', ' Philadelphia']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['Toronto']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['London']
# ['Flexible']
# ['NYC']
# ['Flexible']
# ['Ladysmith BC']
# ['Flexible']
# ['Los Angeles']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['NYC']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['Ladysmith BC']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['North America', ' Flexible']
# ['Chicago']
# ['North America', ' Flexible']
# ['NYC']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['Boston']
# ['North America', ' Flexible']
# ['DC', ' Philadelphia']
# ['North America', ' Flexible']
# ['nan']
# ['North America', ' Flexible']
# ['nan']
# ['North America', ' Flexible']
# ['nan']
# ['North America', ' Flexible']
# ['Toronto']
# ['North America', ' Flexible']
# ['nan']
# ['North America', ' Flexible']
# ['London']
# ['North America', ' Flexible']
# ['NYC']
# ['North America', ' Flexible']
# ['Ladysmith BC']
# ['North America', ' Flexible']
# ['Los Angeles']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['NYC']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['Indonesia']
# ['San Francisco Bay Area']
# ['Indonesia']
# ['San Francisco Bay Area']
# ['Indonesia']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Indonesia']
# ['Chicago']
# ['Indonesia']
# ['NYC']
# ['Indonesia']
# ['San Francisco Bay Area']
# ['Indonesia']
# ['Boston']
# ['Indonesia']
# ['DC', ' Philadelphia']
# ['Indonesia']
# ['nan']
# ['Indonesia']
# ['nan']
# ['Indonesia']
# ['nan']
# ['Indonesia']
# ['Toronto']
# ['Indonesia']
# ['nan']
# ['Indonesia']
# ['London']
# ['Indonesia']
# ['NYC']
# ['Indonesia']
# ['Ladysmith BC']
# ['Indonesia']
# ['Los Angeles']
# ['Indonesia']
# ['San Francisco Bay Area']
# ['Indonesia']
# ['San Francisco Bay Area']
# ['Indonesia']
# ['NYC']
# ['Indonesia']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['London']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area', ' Berkeley']
# ['Central Europe', ' UK', ' Oxford']
# ['Los Angeles', ' Western US']
# ['Central Europe', ' UK', ' Oxford']
# ['DC']
# ['Central Europe', ' UK', ' Oxford']
# ['nan']
# ['Central Europe', ' UK', ' Oxford']
# ['Southern US']
# ['Central Europe', ' UK', ' Oxford']
# ['NYC']
# ['Central Europe', ' UK', ' Oxford']
# ['nan']
# ['Central Europe', ' UK', ' Oxford']
# ['Central Europe']
# ['Central Europe', ' UK', ' Oxford']
# ['Los Angeles']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['NYC']
# ['Central Europe', ' UK', ' Oxford']
# ['nan']
# ['Central Europe', ' UK', ' Oxford']
# ['NYC']
# ['Central Europe', ' UK', ' Oxford']
# ['Asia']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['NYC']
# ['Central Europe', ' UK', ' Oxford']
# ['Seattle', ' WA', ' Western US', ' North America']
# ['Central Europe', ' UK', ' Oxford']
# ['London', ' UK']
# ['Central Europe', ' UK', ' Oxford']
# ['UK']
# ['Central Europe', ' UK', ' Oxford']
# ['NYC', ' NJ']
# ['Central Europe', ' UK', ' Oxford']
# ['Brazil']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['CT', ' New Haven']
# ['Central Europe', ' UK', ' Oxford']
# ['Berlin']
# ['Central Europe', ' UK', ' Oxford']
# ['Berlin']
# ['Central Europe', ' UK', ' Oxford']
# ['Berkeley', ' San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['London']
# ['Central Europe', ' UK', ' Oxford']
# ['PA', ' Philadelphia']
# ['Central Europe', ' UK', ' Oxford']
# ['South of France']
# ['Central Europe', ' UK', ' Oxford']
# ['NYC']
# ['Central Europe', ' UK', ' Oxford']
# ['Denver', ' Colorado']
# ['Central Europe', ' UK', ' Oxford']
# ['Western US']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['Collingswood', ' NJ']
# ['DC']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['DC']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['DC']
# ['Chicago']
# ['DC']
# ['NYC']
# ['DC']
# ['San Francisco Bay Area']
# ['DC']
# ['Boston']
# ['DC']
# ['DC', ' Philadelphia']
# ['DC']
# ['nan']
# ['DC']
# ['nan']
# ['DC']
# ['nan']
# ['DC']
# ['Toronto']
# ['DC']
# ['nan']
# ['DC']
# ['London']
# ['DC']
# ['NYC']
# ['DC']
# ['Ladysmith BC']
# ['DC']
# ['Los Angeles']
# ['DC']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['DC']
# ['NYC']
# ['DC']
# ['San Francisco Bay Area']
# ['DC']
# ['Ladysmith BC']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['Chicago']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['NYC']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['Boston']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['nan']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['nan']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['nan']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['Toronto']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['nan']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['London']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['NYC']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['Ladysmith BC']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['Los Angeles']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['NYC']
# ['San Francisco Bay Area', ' NYC', ' Los Angeles', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['London', ' UK']
# ['Chicago']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['Boston']
# ['London', ' UK']
# ['DC', ' Philadelphia']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['Toronto']
# ['London', ' UK']
# ['nan']
# ['London', ' UK']
# ['London']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['Ladysmith BC']
# ['London', ' UK']
# ['Los Angeles']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['NYC']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Flexible']
# ['Chicago']
# ['Flexible']
# ['NYC']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['Boston']
# ['Flexible']
# ['DC', ' Philadelphia']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['Toronto']
# ['Flexible']
# ['nan']
# ['Flexible']
# ['London']
# ['Flexible']
# ['NYC']
# ['Flexible']
# ['Ladysmith BC']
# ['Flexible']
# ['Los Angeles']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Flexible']
# ['NYC']
# ['Flexible']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['Spain']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area']
# ['Norway']
# ['San Francisco Bay Area']
# ['Israel']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible', ' NY']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Sacramento', ' Monterey']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['Los Angeles', ' Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['Flexible', ' UK']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' North America']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Boston']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Seoul']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Seattle', ' WA', ' Flexible']
# ['San Francisco Bay Area']
# ['WI']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Boston', ' MA']
# ['San Francisco Bay Area']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' London', ' Brighton', ' Seattle', ' Southern US', ' TX', ' NJ', ' Sweden', ' Los Angeles', ' Sydney Australia', ' ON', ' North Carolina', ' Boston', ' North America', ' Toronto', ' Canada', ' Flexible', ' Philadelphia', ' UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Seattle', ' Boston', ' Western US']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['Brighton']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['PA']
# ['San Francisco Bay Area']
# ['Central Europe', ' Berlin']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Los Angeles']
# ['San Francisco Bay Area']
# ['Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Oregon']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' NYC']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['Seoul', ' Asia', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Amsterdam']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Vancouver']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area', ' Austin']
# ['San Francisco Bay Area']
# ['Oxford']
# ['San Francisco Bay Area']
# ['NY', ' NYC']
# ['San Francisco Bay Area']
# ['London', ' Brighton']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['San Francisco Bay Area']
# ['London']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['London']
# ['London']
# ['San Francisco Bay Area', ' Berkeley']
# ['London']
# ['Los Angeles', ' Western US']
# ['London']
# ['DC']
# ['London']
# ['nan']
# ['London']
# ['Southern US']
# ['London']
# ['NYC']
# ['London']
# ['nan']
# ['London']
# ['Central Europe']
# ...
# ['Western US']
# ['North America']
# ['Western US']
# ['DC', ' North America', ' Flexible']
# ['Western US']
# ['Central Europe', ' UK', ' Oxford']
# ['Western US']
# ['London']
# ['Western US']
# ['Berlin']
# ['Western US']
# ['Spain']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['Austin']
# ['Western US']
# ['London']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Western US']
# ['Norway']
# ['Western US']
# ['Israel']
# ['Western US']
# ['London', ' UK']
# ['Western US']
# ['London']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['London']
# ['Western US']
# ['NYC', ' Flexible', ' NY']
# ['Western US']
# ['North America']
# ['Western US']
# ['London']
# ['Western US']
# ['Berlin']
# ['Western US']
# ['London', ' UK']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['London', ' Berlin', ' Central Europe']
# ['Western US']
# ['London', ' UK']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['NYC']
# ['Western US']
# ['NYC', ' NY']
# ['Western US']
# ['London', ' UK']
# ['Western US']
# ['Asia']
# ['Western US']
# ['San Francisco Bay Area', ' Sacramento', ' Monterey']
# ['Western US']
# ['Flexible']
# ['Western US']
# ['Chicago']
# ['Western US']
# ['Los Angeles', ' Chicago']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['London', ' Flexible', ' Asia']
# ['Western US']
# ['Flexible', ' UK']
# ['Western US']
# ['Chicago']
# ['Western US']
# ['NYC']
# ['Western US']
# ['NYC', ' NY', ' North America']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['Boston']
# ['Western US']
# ['UK']
# ['Western US']
# ['Central Europe']
# ['Western US']
# ['DC', ' Philadelphia']
# ['Western US']
# ['Central Europe']
# ['Western US']
# ['Seoul']
# ['Western US']
# ['nan']
# ['Western US']
# ['London']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['nan']
# ['Western US']
# ['Asia']
# ['Western US']
# ['nan']
# ['Western US']
# ['Seattle', ' WA', ' Flexible']
# ['Western US']
# ['WI']
# ['Western US']
# ['North America', ' Flexible']
# ['Western US']
# ['nan']
# ['Western US']
# ['nan']
# ['Western US']
# ['Boston', ' MA']
# ['Western US']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['Western US']
# ['Central Europe']
# ['Western US']
# ['Toronto']
# ['Western US']
# ['NYC', ' NY', ' London', ' Brighton', ' Seattle', ' Southern US', ' TX', ' NJ', ' Sweden', ' Los Angeles', ' Sydney Australia', ' ON', ' North Carolina', ' Boston', ' North America', ' Toronto', ' Canada', ' Flexible', ' Philadelphia', ' UK']
# ['Western US']
# ['Central Europe']
# ['Western US']
# ['Los Angeles']
# ['Western US']
# ['nan']
# ['Western US']
# ['London']
# ['Western US']
# ['UK']
# ['Western US']
# ['San Francisco Bay Area', ' Seattle', ' Boston', ' Western US']
# ['Western US']
# ['London', ' UK']
# ['Western US']
# ['Austin']
# ['Western US']
# ['Brighton']
# ['Western US']
# ['nan']
# ['Western US']
# ['PA']
# ['Western US']
# ['Central Europe', ' Berlin']
# ['Western US']
# ['Central Europe']
# ['Western US']
# ['San Francisco Bay Area', ' Los Angeles']
# ['Western US']
# ['Berlin', ' Central Europe']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['NYC']
# ['Western US']
# ['Oregon']
# ['Western US']
# ['Ladysmith BC']
# ['Western US']
# ['NYC', ' Flexible']
# ['Western US']
# ['San Francisco Bay Area', ' NYC']
# ['Western US']
# ['London']
# ['Western US']
# ['Los Angeles']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['Seoul', ' Asia', ' Flexible']
# ['Western US']
# ['Central Europe']
# ['Western US']
# ['Chicago']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['NYC']
# ['Western US']
# ['Los Angeles']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['DC']
# ['Western US']
# ['Amsterdam']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['DC']
# ['Western US']
# ['Vancouver']
# ['Western US']
# ['San Francisco Bay Area', ' Austin']
# ['Western US']
# ['Oxford']
# ['Western US']
# ['NY', ' NYC']
# ['Western US']
# ['London', ' Brighton']
# ['Western US']
# ['San Francisco Bay Area']
# ['Western US']
# ['London']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area', ' Berkeley']
# ['London']
# ['Los Angeles', ' Western US']
# ['London']
# ['DC']
# ['London']
# ['nan']
# ['London']
# ['Southern US']
# ['London']
# ['NYC']
# ['London']
# ['nan']
# ['London']
# ['Central Europe']
# ['London']
# ['Los Angeles']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['NYC']
# ['London']
# ['nan']
# ['London']
# ['NYC']
# ['London']
# ['Asia']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['NYC']
# ['London']
# ['Seattle', ' WA', ' Western US', ' North America']
# ['London']
# ['UK']
# ['London']
# ['NYC', ' NJ']
# ['London']
# ['Brazil']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['CT', ' New Haven']
# ['London']
# ['Berlin']
# ['London']
# ['Berlin']
# ['London']
# ['Berkeley', ' San Francisco Bay Area']
# ['London']
# ['PA', ' Philadelphia']
# ['London']
# ['South of France']
# ['London']
# ['NYC']
# ['London']
# ['Denver', ' Colorado']
# ['London']
# ['Western US']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Sacramento']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['DC', ' North America', ' Flexible']
# ['San Francisco Bay Area']
# ['Central Europe', ' UK', ' Oxford']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['London', ' Boston']
# ['San Francisco Bay Area']
# ['Spain']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['North America', ' Flexible', ' Chicago', ' Colorado', ' TX']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['San Francisco Bay Area']
# ['Norway']
# ['San Francisco Bay Area']
# ['Israel']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible', ' NY']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['London', ' Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Western US']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Flexible']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['Los Angeles', ' Chicago']
# ['San Francisco Bay Area']
# ['London', ' Flexible', ' Asia']
# ['San Francisco Bay Area']
# ['Flexible', ' UK']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' North America']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['Boston']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['DC', ' Philadelphia']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Seoul']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Asia']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Seattle', ' WA', ' Flexible']
# ['San Francisco Bay Area']
# ['WI']
# ['San Francisco Bay Area']
# ['North America', ' Flexible']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Boston', ' MA']
# ['San Francisco Bay Area']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['NYC', ' NY', ' London', ' Brighton', ' Seattle', ' Southern US', ' TX', ' NJ', ' Sweden', ' Los Angeles', ' Sydney Australia', ' ON', ' North Carolina', ' Boston', ' North America', ' Toronto', ' Canada', ' Flexible', ' Philadelphia', ' UK']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['UK']
# ['San Francisco Bay Area']
# ['London', ' UK']
# ['San Francisco Bay Area']
# ['Austin']
# ['San Francisco Bay Area']
# ['Brighton']
# ['San Francisco Bay Area']
# ['nan']
# ['San Francisco Bay Area']
# ['PA']
# ['San Francisco Bay Area']
# ['Central Europe', ' Berlin']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Berlin', ' Central Europe']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Oregon']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['NYC', ' Flexible']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['Seoul', ' Asia', ' Flexible']
# ['San Francisco Bay Area']
# ['Toronto']
# ['San Francisco Bay Area']
# ['Central Europe']
# ['San Francisco Bay Area']
# ['Chicago']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['NYC']
# ['San Francisco Bay Area']
# ['Los Angeles']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Amsterdam']
# ['San Francisco Bay Area']
# ['DC']
# ['San Francisco Bay Area']
# ['Vancouver']
# ['San Francisco Bay Area']
# ['Oxford']
# ['San Francisco Bay Area']
# ['NY', ' NYC']
# ['San Francisco Bay Area']
# ['London', ' Brighton']
# ['San Francisco Bay Area']
# ['North America']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Cambridge', ' MA']
# ['San Francisco Bay Area']
# ['London']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['Ladysmith BC']
# ['Central Europe', ' South of France']
# ['Ladysmith BC']
# ['San Francisco Bay Area', ' Philadelphia']
# ['Ladysmith BC']
# ['Flexible']
# ['Ladysmith BC']
# ['DC']
# ['Ladysmith BC']
# ['Flexible', ' Colorado']
# ['Ladysmith BC']
# ['San Francisco Bay Area', ' Berkeley']
# ['Ladysmith BC']
# ['DC']
# ['Ladysmith BC']
# ['Southern US']
# ['Ladysmith BC']
# ['nan']
# ['Ladysmith BC']
# ['NYC']
# ['Ladysmith BC']
# ['nan']
# ['Ladysmith BC']
# ['nan']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['UK']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['NYC', ' Portland', ' London', ' Seattle', ' Vancouver', ' Somerville', ' Central Europe', ' Boston', ' Cambridge', ' DC', ' MA']
# ['Ladysmith BC']
# ['London']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['UK']
# ['Ladysmith BC']
# ['North America']
# ['Ladysmith BC']
# ['nan']
# ['Ladysmith BC']
# ['Philadelphia', ' PA']
# ['Ladysmith BC']
# ['San Francisco Bay Area', ' Berlin', ' Asheville', ' Vancouver Island']
# ['Ladysmith BC']
# ['London']
# ['Ladysmith BC']
# ['San Francisco Bay Area']
# ['Ladysmith BC']
# ['NY']
# ['NY']
# ['San Francisco Bay Area']
# ['NY']
# ['San Francisco Bay Area']
# ['NY']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['NY']
# ['Chicago']
# ['NY']
# ['NYC']
# ['NY']
# ['San Francisco Bay Area']
# ['NY']
# ['Boston']
# ['NY']
# ['DC', ' Philadelphia']
# ['NY']
# ['nan']
# ['NY']
# ['nan']
# ['NY']
# ['nan']
# ['NY']
# ['Toronto']
# ['NY']
# ['nan']
# ['NY']
# ['London']
# ['NY']
# ['NYC']
# ['NY']
# ['Ladysmith BC']
# ['NY']
# ['Los Angeles']
# ['NY']
# ['San Francisco Bay Area']
# ['NY']
# ['San Francisco Bay Area']
# ['NY']
# ['NYC']
# ['NY']
# ['San Francisco Bay Area']
# ['NY']
# ['Ladysmith BC']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['Sacramento']
# ['Collingswood', ' NJ']
# ['North America']
# ['Collingswood', ' NJ']
# ['DC', ' North America', ' Flexible']
# ['Collingswood', ' NJ']
# ['Central Europe', ' UK', ' Oxford']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['Berlin']
# ['Collingswood', ' NJ']
# ['Spain']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['Austin']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['North America', ' Western US', ' Seattle', ' WA']
# ['Collingswood', ' NJ']
# ['Norway']
# ['Collingswood', ' NJ']
# ['Israel']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['NYC', ' Flexible', ' NY']
# ['Collingswood', ' NJ']
# ['North America']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['Berlin']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['London', ' Berlin', ' Central Europe']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['NYC']
# ['Collingswood', ' NJ']
# ['NYC', ' NY']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['Collingswood', ' NJ']
# ['Asia']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area', ' Sacramento', ' Monterey']
# ['Collingswood', ' NJ']
# ['Flexible']
# ['Collingswood', ' NJ']
# ['Chicago']
# ['Collingswood', ' NJ']
# ['Los Angeles', ' Chicago']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['London', ' Flexible', ' Asia']
# ['Collingswood', ' NJ']
# ['Flexible', ' UK']
# ['Collingswood', ' NJ']
# ['Chicago']
# ['Collingswood', ' NJ']
# ['NYC']
# ['Collingswood', ' NJ']
# ['NYC', ' NY', ' North America']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['Boston']
# ['Collingswood', ' NJ']
# ['UK']
# ['Collingswood', ' NJ']
# ['Central Europe']
# ['Collingswood', ' NJ']
# ['DC', ' Philadelphia']
# ['Collingswood', ' NJ']
# ['Central Europe']
# ['Collingswood', ' NJ']
# ['Seoul']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['Asia']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['Seattle', ' WA', ' Flexible']
# ['Collingswood', ' NJ']
# ['WI']
# ['Collingswood', ' NJ']
# ['North America', ' Flexible']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['Boston', ' MA']
# ['Collingswood', ' NJ']
# ['Central Europe', ' London', ' Amsterdam', ' South of France']
# ['Collingswood', ' NJ']
# ['Central Europe']
# ['Collingswood', ' NJ']
# ['Toronto']
# ['Collingswood', ' NJ']
# ['Central Europe']
# ['Collingswood', ' NJ']
# ['Los Angeles']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['UK']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area', ' Seattle', ' Boston', ' Western US']
# ['Collingswood', ' NJ']
# ['London', ' UK']
# ['Collingswood', ' NJ']
# ['Austin']
# ['Collingswood', ' NJ']
# ['Brighton']
# ['Collingswood', ' NJ']
# ['nan']
# ['Collingswood', ' NJ']
# ['PA']
# ['Collingswood', ' NJ']
# ['Central Europe', ' Berlin']
# ['Collingswood', ' NJ']
# ['Central Europe']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area', ' Los Angeles']
# ['Collingswood', ' NJ']
# ['Berlin', ' Central Europe']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['NYC']
# ['Collingswood', ' NJ']
# ['Oregon']
# ['Collingswood', ' NJ']
# ['Ladysmith BC']
# ['Collingswood', ' NJ']
# ['NYC', ' Flexible']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area', ' NYC']
# ['Collingswood', ' NJ']
# ['London']
# ['Collingswood', ' NJ']
# ['Los Angeles']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['Seoul', ' Asia', ' Flexible']
# ['Collingswood', ' NJ']
# ['Central Europe']
# ['Collingswood', ' NJ']
# ['Chicago']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['NYC']
# ['Collingswood', ' NJ']
# ['Los Angeles']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['DC']
# ['Collingswood', ' NJ']
# ['Amsterdam']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['DC']
# ['Collingswood', ' NJ']
# ['Vancouver']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area', ' Austin']
# ['Collingswood', ' NJ']
# ['Oxford']
# ['Collingswood', ' NJ']
# ['NY', ' NYC']
# ['Collingswood', ' NJ']
# ['London', ' Brighton']
# ['Collingswood', ' NJ']
# ['San Francisco Bay Area']
# ['Collingswood', ' NJ']
# ['London']

# %%
print(all_matches)
print(len(all_matches))
df
# Out:
# ['0:6', '0:8', '0:11', '0:21', '0:28', '0:36', '0:42', '0:47', '0:52', '0:59', '0:88', '0:92', '0:94', '0:95', '0:96', '0:101', '0:106', '0:110', '0:111', '0:123', '0:124', '0:131', '0:140', '0:157', '0:158', '0:166', '0:168', '0:171', '0:174', '0:175', '0:176', '0:182', '0:183', '0:188', '0:191', '0:192', '0:194', '0:202', '0:214', '0:217', '0:224', '0:225', '0:226', '0:229', '0:233', '0:236', '0:240', '0:242', '0:245', '0:247', '0:251', '0:254', '0:258', '0:265', '0:266', '0:270', '0:273', '0:285', '0:291', '0:294', '0:300', '0:302', '0:311', '0:321', '0:325', '0:331', '0:333', '0:338', '0:352', '0:355', '0:361', '0:368', '0:387', '0:389', '0:391', '0:393', '0:407', '0:408', '0:409', '0:412', '0:415', '0:427', '0:430', '0:434', '0:435', '0:438', '0:458', '0:470', '0:473', '2:6', '2:8', '2:11', '2:21', '2:28', '2:36', '2:42', '2:47', '2:52', '2:59', '2:88', '2:92', '2:94', '2:95', '2:96', '2:101', '2:106', '2:110', '2:111', '2:123', '2:124', '2:131', '2:140', '2:157', '2:158', '2:166', '2:168', '2:171', '2:174', '2:176', '2:182', '2:183', '2:188', '2:191', '2:192', '2:194', '2:202', '2:214', '2:217', '2:224', '2:225', '2:226', '2:229', '2:233', '2:236', '2:240', '2:242', '2:245', '2:247', '2:251', '2:254', '2:258', '2:265', '2:266', '2:270', '2:273', '2:285', '2:291', '2:294', '2:300', '2:302', '2:311', '2:321', '2:325', '2:331', '2:333', '2:338', '2:352', '2:355', '2:361', '2:368', '2:387', '2:391', '2:393', '2:407', '2:408', '2:409', '2:412', '2:415', '2:427', '2:430', '2:434', '2:435', '2:438', '2:458', '2:473', '3:6', '3:8', '3:11', '3:21', '3:28', '3:36', '3:42', '3:47', '3:49', '3:52', '3:59', '3:63', '3:88', '3:92', '3:94', '3:95', '3:96', '3:101', '3:106', '3:110', '3:111', '3:123', '3:124', '3:131', '3:140', '3:157', '3:158', '3:166', '3:168', '3:171', '3:174', '3:175', '3:176', '3:182', '3:183', '3:188', '3:191', '3:192', '3:194', '3:202', '3:205', '3:214', '3:217', '3:218', '3:224', '3:225', '3:226', '3:229', '3:233', '3:236', '3:240', '3:242', '3:245', '3:247', '3:251', '3:254', '3:258', '3:265', '3:266', '3:270', '3:273', '3:285', '3:291', '3:294', '3:300', '3:302', '3:311', '3:321', '3:325', '3:331', '3:333', '3:338', '3:352', '3:355', '3:361', '3:368', '3:383', '3:387', '3:389', '3:391', '3:393', '3:403', '3:407', '3:408', '3:409', '3:412', '3:415', '3:427', '3:430', '3:434', '3:435', '3:438', '3:458', '3:460', '3:470', '3:473', '5:6', '5:8', '5:11', '5:21', '5:28', '5:36', '5:42', '5:47', '5:52', '5:59', '5:77', '5:88', '5:92', '5:94', '5:95', '5:96', '5:101', '5:106', '5:110', '5:111', '5:123', '5:124', '5:131', '5:140', '5:157', '5:158', '5:166', '5:168', '5:171', '5:174', '5:176', '5:182', '5:183', '5:188', '5:191', '5:192', '5:194', '5:202', '5:214', '5:217', '5:218', '5:224', '5:225', '5:226', '5:229', '5:233', '5:236', '5:240', '5:242', '5:245', '5:247', '5:251', '5:254', '5:258', '5:265', '5:266', '5:270', '5:273', '5:285', '5:291', '5:294', '5:300', '5:302', '5:311', '5:321', '5:325', '5:331', '5:333', '5:338', '5:352', '5:355', '5:361', '5:368', '5:387', '5:391', '5:393', '5:407', '5:408', '5:409', '5:412', '5:415', '5:427', '5:430', '5:434', '5:435', '5:438', '5:458', '5:473', '6:7', '6:9', '6:10', '6:11', '6:12', '6:13', '6:15', '6:17', '6:18', '6:19', '6:20', '6:22', '6:24', '6:25', '6:27', '6:30', '6:31', '6:33', '6:34', '6:35', '6:36', '6:39', '6:41', '6:44', '6:45', '6:46', '6:47', '6:51', '6:54', '6:56', '6:58', '6:60', '6:61', '6:62', '6:65', '6:68', '6:69', '6:71', '6:75', '6:76', '6:79', '6:80', '6:81', '6:82', '6:83', '6:85', '6:88', '6:89', '6:92', '6:93', '6:97', '6:98', '6:99', '6:100', '6:104', '6:105', '6:113', '6:115', '6:116', '6:118', '6:119', '6:120', '6:121', '6:122', '6:124', '6:125', '6:128', '6:136', '6:139', '6:141', '6:144', '6:146', '6:147', '6:148', '6:149', '6:152', '6:153', '6:154', '6:162', '6:163', '6:165', '6:169', '6:172', '6:173', '6:175', '6:176', '6:177', '6:179', '6:184', '6:187', '6:190', '6:197', '6:198', '6:199', '6:200', '6:204', '6:206', '6:209', '6:213', '6: ...
# 15539
#                Name                                        ProfileLink  Age  \
# 0             Gabin  https://docs.google.com/document/d/1ymul6X3DQH...   25
# 2            Callum  https://docs.google.com/document/d/16Li0PY9WG5...   40
# 3        Ari Zerner                     https://arizerner.com/date-me/   27
# 5              Mike  https://docs.google.com/document/d/1AvSdS2EUh4...   31
# 6          Alicia C  https://aecombs.notion.site/Date-Alicia-471a13...   33
# ..              ...                                                ...  ...
# 473  Rachel Clifton  https://docs.google.com/document/d/1_Xjg6U_n5W...   24
# 474            Dony  https://docs.google.com/document/d/1PfWxS-Xl_K...   27
# 477  Blaïse (bless)  https://docs.google.com/document/d/1ndGs9G9SvG...   38
# 478   Brian Tomasik        https://briantomasik.com/my-dating-profile/   35
# 479             Wes  https://docs.google.com/document/d/1w2jH3CRis1...   39
#
#     Gender InterestedIn       Style  \
# 0        M        F, NB         Any
# 2        M            F        mono
# 3        M        F, NB        poly
# 5        M            F        mono
# 6        F     F, M, NB        poly
# ..     ...          ...         ...
# 473      F            M  poly, mono
# 474      M     F, M, NB         NaN
# 477     NB            M        mono
# 478      M        F, NB        mono
# 479      M            F        poly
#
#                                       Location LocationFlexibility  \
# 0              Central Europe, South of France                Some
# 2                                           UK            Flexible
# 3         San Francisco Bay Area, Philadelphia                Some
# 5    North America, Flexible, Philadelphia, PA            Flexible
# 6                       San Francisco Bay Area                Some
# ..                                         ...                 ...
# 473                                     London            Flexible
# 474                     San Francisco Bay Area                 NaN
# 477                               Ladysmith BC                 NaN
# 478                                         NY            Flexible
# 479                           Collingswood, NJ                 NaN
#
#                                      Contact LastUpdated  \
# 0                   GabinDatingDoc@proton.me  2025-03-07
# 2                callumcallum109@outlook.com  2025-03-04
# 3                             ari@zerner.com  2025-02-24
# 5                          please see doc :)  2025-02-20
# 6                  alicia.combs.92@gmail.com  2025-02-18
# ..                                       ...         ...
# 473                   twitter.com/rachelclif  2023-01-23
# 474  https://calendly.com/donychristie/30min  2022-10-16
# 477                     Academia_nut@shaw.ca  2022-10-14
# 478                                      NaN  2022-10-01
# 479                                      NaN  2022-09-29
#
#                                            ProfileText  \
# 0    ﻿Hi!\r\nThis is a dating doc, I’m a 25 year ol...
# 2    ﻿In as many words\r\n\r\n\r\nTo love and be lo...
# 3    Ari's Date Me Doc | Ari Zerner's Demesne\nAri ...
# 5    ﻿Mike’s Date-Me Doc\r\n\r\n\r\n\r\n\r\nHi, tha...
# 6    Your connected workspace for wiki, docs & proj...
# ..                                                 ...
# 473  ﻿This document is a social experiment. \r\nIt’...
# 474                                                  ﻿
# 477  ﻿Dating Stephen Blaïse Saint Clare\r\n\r\n\r\n...
# 478  My dating profile\nHome\n•\nWritings\nMy datin...
# 479  ﻿BESPOKE 1983 NONMONOGAMOUS DAD MODEL, AVAILAB...
#
#                                                matches
# 0    [6, 8, 11, 21, 28, 36, 42, 47, 52, 59, 88, 92,...
# 2    [6, 8, 11, 21, 28, 36, 42, 47, 52, 59, 88, 92,...
# 3    [6, 8, 11, 21, 28, 36, 42, 47, 49, 52, 59, 63,...
# 5    [6, 8, 11, 21, 28, 36, 42, 47, 52, 59, 77, 88,...
# 6    [7, 9, 10, 11, 12, 13, 15, 17, 18, 19, 20, 22,...
# ..                                                 ...
# 473                                              [478]
# 474                                                 []
# 477                                                 []
# 478                                                 []
# 479                                                 []
#
# [342 rows x 12 columns]
