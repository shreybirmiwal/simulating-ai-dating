# %%
import pandas as pd


df = pd.read_csv('data.csv')

# %%
# delete every row that has  'could not extract' in the row some text

df = df[~df.apply(lambda row: row.astype(str).str.contains('Could not extract').any(), axis=1)]

# %%
df
# Out:
#                Name                                        ProfileLink  Age  \
# 0             Gabin  https://docs.google.com/document/d/1ymul6X3DQH...   25
# 2            Callum  https://docs.google.com/document/d/16Li0PY9WG5...   40
# 3        Ari Zerner                     https://arizerner.com/date-me/   27
# 5              Mike  https://docs.google.com/document/d/1AvSdS2EUh4...   31
# 6          Alicia C  https://aecombs.notion.site/Date-Alicia-471a13...   33
# ..              ...                                                ...  ...
# 473  Rachel Clifton  https://docs.google.com/document/d/1_Xjg6U_n5W...   24
# 474            Dony  https://docs.google.com/document/d/1PfWxS-Xl_K...   27
# 477  Blaïse (bless)  https://docs.google.com/document/d/1ndGs9G9SvG...   38
# 478   Brian Tomasik        https://briantomasik.com/my-dating-profile/   35
# 479             Wes  https://docs.google.com/document/d/1w2jH3CRis1...   39
#
#     Gender InterestedIn       Style  \
# 0        M        F, NB         Any
# 2        M            F        mono
# 3        M        F, NB        poly
# 5        M            F        mono
# 6        F     F, M, NB        poly
# ..     ...          ...         ...
# 473      F            M  poly, mono
# 474      M     F, M, NB         NaN
# 477     NB            M        mono
# 478      M        F, NB        mono
# 479      M            F        poly
#
#                                       Location LocationFlexibility  \
# 0              Central Europe, South of France                Some
# 2                                           UK            Flexible
# 3         San Francisco Bay Area, Philadelphia                Some
# 5    North America, Flexible, Philadelphia, PA            Flexible
# 6                       San Francisco Bay Area                Some
# ..                                         ...                 ...
# 473                                     London            Flexible
# 474                     San Francisco Bay Area                 NaN
# 477                               Ladysmith BC                 NaN
# 478                                         NY            Flexible
# 479                           Collingswood, NJ                 NaN
#
#                                      Contact LastUpdated  \
# 0                   GabinDatingDoc@proton.me  2025-03-07
# 2                callumcallum109@outlook.com  2025-03-04
# 3                             ari@zerner.com  2025-02-24
# 5                          please see doc :)  2025-02-20
# 6                  alicia.combs.92@gmail.com  2025-02-18
# ..                                       ...         ...
# 473                   twitter.com/rachelclif  2023-01-23
# 474  https://calendly.com/donychristie/30min  2022-10-16
# 477                     Academia_nut@shaw.ca  2022-10-14
# 478                                      NaN  2022-10-01
# 479                                      NaN  2022-09-29
#
#                                            ProfileText
# 0    ﻿Hi!\r\nThis is a dating doc, I’m a 25 year ol...
# 2    ﻿In as many words\r\n\r\n\r\nTo love and be lo...
# 3    Ari's Date Me Doc | Ari Zerner's Demesne\nAri ...
# 5    ﻿Mike’s Date-Me Doc\r\n\r\n\r\n\r\n\r\nHi, tha...
# 6    Your connected workspace for wiki, docs & proj...
# ..                                                 ...
# 473  ﻿This document is a social experiment. \r\nIt’...
# 474                                                  ﻿
# 477  ﻿Dating Stephen Blaïse Saint Clare\r\n\r\n\r\n...
# 478  My dating profile\nHome\n•\nWritings\nMy datin...
# 479  ﻿BESPOKE 1983 NONMONOGAMOUS DAD MODEL, AVAILAB...
#
# [342 rows x 11 columns]

# %%
all_matches = []  # Global list to track matched pairs (stored as strings like "rowA:rowB")

def get_matches(row):
    my_gen = row['Gender'].strip()
    my_want = [x.strip() for x in str(row['InterestedIn']).split(',')]
    
    matches = []  # Initialize the matches list for this row
    
    for idx, other_row in df.iterrows():
        if idx == row.name:  # Skip self
            continue
        
        # Check if other's gender is in my desired list
        if other_row['Gender'].strip() in my_want:
            # Check if my gender is in their desired list
            other_want = [x.strip() for x in str(other_row['InterestedIn']).split(',')]
            if my_gen in other_want:
                # Check if the pair already exists in either order
                pair1 = f"{row.name}:{other_row.name}"
                pair2 = f"{other_row.name}:{row.name}"
                
                if pair1 not in all_matches and pair2 not in all_matches:
                    # If not present, add to all_matches and record the match
                    all_matches.append(pair1)  # Track the pair in one direction
                    matches.append(other_row.name)  # Append the other user's name
                    
    return matches  # Return the matches list (not the entire row)

# Apply the function and assign to 'matches' column
df['matches'] = df.apply(get_matches, axis=1)

# %%
print(all_matches)
print(len(all_matches))
df
# Out:
# ['0:6', '0:8', '0:11', '0:21', '0:28', '0:36', '0:42', '0:47', '0:49', '0:52', '0:59', '0:63', '0:77', '0:88', '0:92', '0:94', '0:95', '0:96', '0:101', '0:106', '0:110', '0:111', '0:123', '0:124', '0:131', '0:140', '0:157', '0:158', '0:166', '0:168', '0:171', '0:174', '0:175', '0:176', '0:182', '0:183', '0:188', '0:191', '0:192', '0:194', '0:195', '0:196', '0:202', '0:205', '0:210', '0:214', '0:217', '0:218', '0:224', '0:225', '0:226', '0:229', '0:233', '0:235', '0:236', '0:240', '0:242', '0:245', '0:247', '0:248', '0:249', '0:251', '0:254', '0:258', '0:262', '0:265', '0:266', '0:270', '0:271', '0:272', '0:273', '0:285', '0:291', '0:294', '0:300', '0:302', '0:311', '0:321', '0:325', '0:331', '0:333', '0:338', '0:340', '0:352', '0:354', '0:355', '0:361', '0:368', '0:376', '0:383', '0:387', '0:389', '0:391', '0:393', '0:403', '0:405', '0:407', '0:408', '0:409', '0:412', '0:415', '0:427', '0:430', '0:434', '0:435', '0:438', '0:458', '0:460', '0:470', '0:473', '0:477', '2:6', '2:8', '2:11', '2:21', '2:28', '2:36', '2:42', '2:47', '2:49', '2:52', '2:59', '2:63', '2:77', '2:88', '2:92', '2:94', '2:95', '2:96', '2:101', '2:106', '2:110', '2:111', '2:123', '2:124', '2:131', '2:140', '2:157', '2:158', '2:166', '2:168', '2:171', '2:174', '2:176', '2:182', '2:183', '2:188', '2:191', '2:192', '2:194', '2:195', '2:196', '2:202', '2:205', '2:210', '2:214', '2:217', '2:218', '2:224', '2:225', '2:226', '2:229', '2:233', '2:235', '2:236', '2:240', '2:242', '2:245', '2:247', '2:248', '2:249', '2:251', '2:254', '2:258', '2:262', '2:265', '2:266', '2:270', '2:271', '2:272', '2:273', '2:285', '2:291', '2:294', '2:300', '2:302', '2:311', '2:321', '2:325', '2:331', '2:333', '2:338', '2:340', '2:352', '2:354', '2:355', '
# ..              ...                                                ...  ...
# 473  Rachel Clifton  https://docs.google.com/document/d/1_Xjg6U_n5W...   24
# 474            Dony  https://docs.google.com/document/d/1PfWxS-Xl_K...   27
# 477  Blaïse (bless)  https://docs.google.com/document/d/1ndGs9G9SvG...   38
# 478   Brian Tomasik        https://briantomasik.com/my-dating-profile/   35
# 479             Wes  https://docs.google.com/document/d/1w2jH3CRis1...   39
#
#     Gender InterestedIn       Style  \
# 0        M        F, NB         Any
# 2        M            F        mono
# 3        M        F, NB        poly
# 5        M            F        mono
# 6        F     F, M, NB        poly
# ..     ...          ...         ...
# 473      F            M  poly, mono
# 474      M     F, M, NB         NaN
# 477     NB            M        mono
# 478      M        F, NB        mono
# 479      M            F        poly
#
#                                       Location LocationFlexibility  \
# 0              Central Europe, South of France                Some
# 2                                           UK            Flexible
# 3         San Francisco Bay Area, Philadelphia                Some
# 5    North America, Flexible, Philadelphia, PA            Flexible
# 6                       San Francisco Bay Area                Some
# ..                                         ...                 ...
# 473                                     London            Flexible
# 474                     San Francisco Bay Area                 NaN
# 477                               Ladysmith BC                 NaN
# 478                                         NY            Flexible
# 479                           Collingswood, NJ                 NaN
#
#                                      Contact LastUpdated  \
# 0                   GabinDatingDoc@proton.me  2025-03-07
# 2                callumcallum109@outlook.com  2025-03-04
# 3                             ari@zerner.com  2025-02-24
# 5                          please see doc :)  2025-02-20
# 6                  alicia.combs.92@gmail.com  2025-02-18
# ..                                       ...         ...
# 473                   twitter.com/rachelclif  2023-01-23
# 474  https://calendly.com/donychristie/30min  2022-10-16
# 477                     Academia_nut@shaw.ca  2022-10-14
# 478                                      NaN  2022-10-01
# 479                                      NaN  2022-09-29
#
#                                            ProfileText  \
# 0    ﻿Hi!\r\nThis is a dating doc, I’m a 25 year ol...
# 2    ﻿In as many words\r\n\r\n\r\nTo love and be lo...
# 3    Ari's Date Me Doc | Ari Zerner's Demesne\nAri ...
# 5    ﻿Mike’s Date-Me Doc\r\n\r\n\r\n\r\n\r\nHi, tha...
# 6    Your connected workspace for wiki, docs & proj...
# ..                                                 ...
# 473  ﻿This document is a social experiment. \r\nIt’...
# 474                                                  ﻿
# 477  ﻿Dating Stephen Blaïse Saint Clare\r\n\r\n\r\n...
# 478  My dating profile\nHome\n•\nWritings\nMy datin...
# 479  ﻿BESPOKE 1983 NONMONOGAMOUS DAD MODEL, AVAILAB...
#
#                                                matches
# 0    [6, 8, 11, 21, 28, 36, 42, 47, 49, 52, 59, 63,...
# 2    [6, 8, 11, 21, 28, 36, 42, 47, 49, 52, 59, 63,...
# 3    [6, 8, 11, 21, 28, 36, 42, 47, 49, 52, 59, 63,...
# 5    [6, 8, 11, 21, 28, 36, 42, 47, 49, 52, 59, 63,...
# 6    [7, 9, 10, 11, 12, 13, 15, 17, 18, 19, 20, 22,...
# ..                                                 ...
# 473                                    [474, 478, 479]
# 474                                              [477]
# 477                                              [478]
# 478                                                 []
# 479                                                 []
#
# [342 rows x 12 columns]
